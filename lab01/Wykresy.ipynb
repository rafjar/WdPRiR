# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("E:\Fizyka Techniczna\WdPRiR\lab01\pomiary_07_11_2021_23_01.csv", names=('Size', 'Time (ns)'))
df.plot(x=0, y=1)
# Out:
# <AxesSubplot:xlabel='Size'>

# %%
df = pd.read_csv("E:\Fizyka Techniczna\WdPRiR\lab01\pomiary_07_11_2021_23_15.csv", names=('Size', 'Time (ms)'))
df.plot(x=0, y=1, figsize=(12, 8))
plt.savefig('wykres.png')
